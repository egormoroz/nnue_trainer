# %%
import ffi
import numpy as np
import matplotlib.pyplot as plt
import chess
from tqdm.auto import tqdm
import numba

# %%
ffi.load_module('../build/Release/satpymod.dll')

# %%
pr = ffi.PackReader('data/d5_1mil.bin')
n = 2_000_000
scores = np.empty(n, dtype=np.int16)
results = np.empty(n, dtype=np.uint8)
keys = np.empty(n, dtype=np.uint64)

k = 0
t = tqdm(total=n)
while True:
    scores[k] = pr.cur_score()
    results[k] = pr.cur_result()
    keys[k] = pr.cur_hash()
    k += 1
    t.update()

    if not pr.next():
        break

t.close()
scores = scores[:k]
results = results[:k]
keys = keys[:k]
# Out:
#   0%|          | 0/2000000 [00:00<?, ?it/s]

# %%
len(np.unique(keys)) / len(keys)
# Out:
# 0.8306094860371046

# %%
clipped = np.clip(scores, -2500, 2500)
plt.hist(clipped)
# Out:
# (array([  4391., 105365., 116248., 107996., 440427., 425658., 103983.,
#         116747.,  96039.,   4034.]),
#  array([-2500., -2000., -1500., -1000.,  -500.,     0.,   500.,  1000.,
#          1500.,  2000.,  2500.]),
#  <BarContainer object of 10 artists>)

# %%
stream = ffi.BatchStream('data/d5_1mil.bin', 'data/d5_1mil.index', 
                         1, 4, 16384, False)

# %%
scores, results = [], []
while True:
    batch = stream.next_batch()
    if batch is None:
        break
    wft_ics, bft_ics, stm, score, result = batch.to_numpy()
#     scores.append((-2*stm  +1) * score)
#     results.append(stm * (1 - result) + (1 - stm) * result)
    scores.append(score)
    results.append(result)

# %%
scores = np.concatenate(scores).astype(np.int16)
results = np.concatenate(results)

# %%
non_draws = results != 0.5
scores = scores[non_draws]
results = results[non_draws]

# %%
np.count_nonzero(results[scores < -1000] >= 0.5)
# Out:
# 11

# %%
plt.hist(np.clip(scores, -2500, 2500))
# Out:
# (array([  1903.,  35252.,  69812.,  58325., 193912., 218118.,  60854.,
#          86433.,  85316.,   4554.]),
#  array([-2500., -2000., -1500., -1000.,  -500.,     0.,   500.,  1000.,
#          1500.,  2000.,  2500.]),
#  <BarContainer object of 10 artists>)

# %%
@numba.njit
def wdl_for_score(score: np.ndarray, result: np.ndarray):
    n = len(score)
    smin, smax = score.min(), score.max()
    acc = np.zeros(smax - smin + 1, dtype=np.float64)
    counts = np.zeros(smax - smin + 1, dtype=np.int32)
    for i in range(n):
        acc[score[i] - smin] += result[i]
        counts[score[i] - smin] += 1
        
    nz = np.nonzero(counts)[0]
    wdl = acc[nz] / counts[nz]
    return nz + smin, wdl

# %%
x, wdl = wdl_for_score(np.clip(scores, -2500, 2500), results)

# %%
plt.plot(x, wdl, '.')
plt.xlim(-2500, 2500)
# Out:
# (-2500.0, 2500.0)

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
class Model:
    def __init__(self, theta0):
        self.theta = theta0
        
    def forward(self, x, y):
        self.x = x
        self.out = sigmoid(x * self.theta)
        self.diff = self.out - y
        self.loss = np.sum(self.diff ** 2) / len(x)
        return self.out, self.loss
    
    def backward(self):
        self.grad = np.dot(2 * self.diff * self.out * (1 - self.out), self.x)
        self.grad /= len(self.x)

# %%
model = Model(1/162)

# %%
y, loss = model.forward(x, wdl)
loss
# Out:
# 0.0054228380506623495

# %%
plt.plot(x, wdl, '.r', x, y, 'b')

# %%
model.backward()
model.theta -= model.grad * 0.001
y, loss = model.forward(x, wdl)
loss, 1/model.theta, model.grad
# Out:
# (0.0049054711062411, 127.0513419519257, -0.07648122846969681)

# %%
1 / model.theta
# Out:
# 123.25411831673622

# %%
idx = np.nonzero(results[scores < -1000] == 2)[0]
idx
# Out:
# array([   2776,    2777,    2778, ..., 1501832, 1501833, 1501834],
#       dtype=int64)

# %%
pr = ffi.PackReader('data/rec.bin')

# %%
scores, results, fens = [], [], []
k = 0
idx = 0
while True:
    scores.append(pr.cur_score())
    results.append(pr.cur_result())
    fens.append(pr.cur_fen())
    if abs(scores[-1]) > 1000 and results[-1] == 2 and k > 6000:
        idx = k
    if not pr.next():
        break
    k += 1

# %%
idx
# Out:
# 7048

# %%
fens[idx]
# Out:
# '5k2/6R1/2p1P3/2P5/PP3p2/5K2/8/8 w - - 100 102'

# %%
import chess

# %%
import time, os

# %%
os.makedirs('svgs', exist_ok=True)

# %%
time.sleep
# Out:
# <function time.sleep>

# %%
import chess.svg

# %%
n = 100
for i in range(n):
    with open(f'svgs/{i}_{scores[i - n]}.svg', 'w') as f:
        board = chess.Board(fens[i - n])
        f.write(chess.svg.board(board))

# %%
print()
chess.Board(fens[-1])
# Out:
# Board('8/R7/2pk4/5pn1/1PP5/3K1P2/P7/8 w - - 0 33')

# %%
fens[idx-10:idx+1]
# Out:
# ['4k3/1R6/2p1P3/2P5/PP3p2/5K2/8/8 w - - 90 97',
#  '4k3/6R1/2p1P3/2P5/PP3p2/5K2/8/8 b - - 91 97',
#  '5k2/6R1/2p1P3/2P5/PP3p2/5K2/8/8 w - - 92 98',
#  '5k2/1R6/2p1P3/2P5/PP3p2/5K2/8/8 b - - 93 98',
#  '4k3/1R6/2p1P3/2P5/PP3p2/5K2/8/8 w - - 94 99',
#  '4k3/6R1/2p1P3/2P5/PP3p2/5K2/8/8 b - - 95 99',
#  '5k2/6R1/2p1P3/2P5/PP3p2/5K2/8/8 w - - 96 100',
#  '5k2/2R5/2p1P3/2P5/PP3p2/5K2/8/8 b - - 97 100',
#  '4k3/2R5/2p1P3/2P5/PP3p2/5K2/8/8 w - - 98 101',
#  '4k3/6R1/2p1P3/2P5/PP3p2/5K2/8/8 b - - 99 101',
#  '5k2/6R1/2p1P3/2P5/PP3p2/5K2/8/8 w - - 100 102']

# %%
scores[-10:]
# Out:
# [802, 946, 883, 913, 832, 853, 861, 981, 911, 1019]

# %%
results[-10:]
# Out:
# [2, 2, 2, 2, 2, 2, 2, 2, 2, 2]

# %%
print('\n'.join(fens[idx-10:idx+1]))
# Out:
# 4k3/1R6/2p1P3/2P5/PP3p2/5K2/8/8 w - - 90 97
# 4k3/6R1/2p1P3/2P5/PP3p2/5K2/8/8 b - - 91 97
# 5k2/6R1/2p1P3/2P5/PP3p2/5K2/8/8 w - - 92 98
# 5k2/1R6/2p1P3/2P5/PP3p2/5K2/8/8 b - - 93 98
# 4k3/1R6/2p1P3/2P5/PP3p2/5K2/8/8 w - - 94 99
# 4k3/6R1/2p1P3/2P5/PP3p2/5K2/8/8 b - - 95 99
# 5k2/6R1/2p1P3/2P5/PP3p2/5K2/8/8 w - - 96 100
# 5k2/2R5/2p1P3/2P5/PP3p2/5K2/8/8 b - - 97 100
# 4k3/2R5/2p1P3/2P5/PP3p2/5K2/8/8 w - - 98 101
# 4k3/6R1/2p1P3/2P5/PP3p2/5K2/8/8 b - - 99 101
# 5k2/6R1/2p1P3/2P5/PP3p2/5K2/8/8 w - - 100 102

# %%
scores[idx]
# Out:
# 1773

# %%
import torch
from model import *
import halfkp

# %%
model = Model(halfkp.N_FT + halfkp.N_VIRT_FT)

# %%
model.load_state_dict(torch.load('d8nn_virtual_scratch/net_80.pt'))
# Out:
# <All keys matched successfully>

# %%
model.ft.weight.max()
# Out:
# tensor(1.5714, grad_fn=<MaxBackward1>)

# %%
model.coalesce_transformer()

# %%
model.ft.weight.max()
# Out:
# tensor(1.8471, grad_fn=<MaxBackward1>)

# %%
'{:.2e}'.format(12.34)
# Out:
# '1.23e+01'
